# %% [markdown]
# # FINM3422 – Lecture 5 In‑Class Notebook (Foundations)
# Use this during the lecture. Cells marked **TODO (lecture)** are completed live in class.

# %%
# %pip install --upgrade pip
# %pip install pandas
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (26.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.0.1)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\zacq2\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# 0) Sanity check: Python, pandas, matplotlib
print('Hello FINM3422 👋')
import sys, pandas as pd, matplotlib.pyplot as plt
sys.version.split()[0]

# %% [markdown]
# ## 1) Load data (prices, monthly)
# We keep a tiny CSV in `data/prices_monthly.csv` with a `Date` column and a few asset columns.

# %%
# TODO (lecture): Run the following code : Create a DataFrame of stock prices for two stocks A and B:
prices = pd.DataFrame({'A':[100,101,103],'B':[100,99,100]}, index=pd.to_datetime(['2020-01-31','2020-02-29','2020-03-31']))
prices.head()

# %%
# TODO (lecture): read the CSV so that Date becomes the index and is parsed as datetime
# Hints: use pd.read_csv('filename.csv', parse_dates=['Date'], index_col='Date')
# Replace the placeholder below.
import pandas as pd
#placeholder for pd.read_csv
prices.head()

# %% [markdown]
# ## 2) Inspect quickly
# Use `.info()`, `.head()`, and `.describe()` to build trust in the table before modelling.

# %%
prices.info()
display(prices.head())
display(prices.describe())

# %% [markdown]
# ## 3) Compute simple returns
# We want fractional monthly returns from prices.

# %%
# TODO (lecture): fill in pct_change to compute returns
# returns = prices.____().dropna()
returns.head()

# %% [markdown]
# ## 4) Ensure monthly labels
# Label the index monthly (no aggregation).

# %%
# TODO (lecture): use asfreq to set a monthly frequency label
# returns = returns.____('ME')
returns.index.freq

# %% [markdown]
# ## 5) Wealth index & one plot
# From returns to an indexed wealth curve (start = 1.0).

# %%
# TODO (lecture): complete the one-liner for wealth index
import matplotlib.pyplot as plt
# wealth = (1 + returns).____().cumprod()
ax = wealth.plot(title='Wealth index (start=1.0)')
ax.set_xlabel('Date'); ax.set_ylabel('Index'); plt.show()

# %% [markdown]
# ## 6) Stretch: handle missing values (choose & document)
# Decide whether to `ffill`, `bfill`, or `dropna`, and *state why*.

# %%
# OPTIONAL TODO (lecture/tutorial): experiment with missing-data handling
returns_clean = returns.dropna()
returns_clean.head()

# %% [markdown]
# ## 7) Save figure (optional)
# Saving outputs makes your work reproducible.

# %%
# OPTIONAL: save plot
import os
os.makedirs('outputs', exist_ok=True)
ax = wealth.plot(title='Wealth index (saved)')
plt.savefig('outputs/wealth_index.png', dpi=150); plt.close()
'Saved to outputs/wealth_index.png'
